# %%
import pandas as pd
# leitura de arquivo da base de dados tabnet do DATASUS
dados = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Alura/Bootcamp de Data Science/data/A152215189_28_143_208_atendimento.csv",
                    encoding="ISO-8859-1",
                    skiprows=3, sep=";",
                    skipfooter=12, thousands=".",
                    decimal=",")
dados.head()

# %%
dados.describe()
# Out:
#         2007/Ago   2007/Set  ...     2021/Mar          Total
# count      27.00      27.00  ...        27.00          27.00
# mean   304952.77  788145.26  ...  24163712.88  6388205992.19
# std    392806.00 1071747.56  ...  35701207.83  8572046016.26
# min      4113.76   11858.63  ...    928756.84   309860092.59
# 25%     46580.42  139423.94  ...   5765750.92  2048683858.60
# 50%    179395.82  418053.58  ...  13069564.31  2660122027.15
# 75%    392985.52  969999.75  ...  28090801.73  8208100569.65
# max   1665349.90 4434168.64  ... 177408317.71 41396408548.81
#
# [8 rows x 165 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 287 entries, Unidade da Federação to Total
# dtypes: float64(165), object(122)
# memory usage: 60.7+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %% [markdown]
# #Visualizações e gráficos

# %%
dados['2018/Ago']
# Out:
# 0      9124967.84
# 1      3040645.05
# 2     16374961.41
# 3      3328230.63
# 4     35618364.04
# 5      2408659.24
# 6      5514866.91
# 7     30838532.57
# 8     16550617.02
# 9     51376446.25
# 10    22634327.48
# 11    19889056.91
# 12    71992572.97
# 13    18221249.82
# 14     9572164.12
# 15    74697458.17
# 16   160484918.69
# 17    25498522.61
# 18    78916904.64
# 19   295669082.46
# 20   131257163.40
# 21    63082199.61
# 22    96799643.23
# 23    18239321.45
# 24    16011187.69
# 25    35408697.61
# 26    20291741.30
# Name: 2018/Ago, dtype: float64

# %%
# https://pandas.pydata.org/docs/index.html
dados['2018/Ago'].mean()
# Out:
# 49364537.15259259

# %%
#dados.plot("Unidade da Federação",('2018/Ago'), kind="bar",figsize=(10,7))
#MÊS MAIS RECENTE
dados.plot("Unidade da Federação",(-2),kind="bar",figsize=(10,7))

# %%
# Desafio 01: Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.
# Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.
# by geanclm in 20/05/2021
import matplotlib.pyplot as plt, matplotlib.ticker as ticker
recente = dados.columns[-2]
ax = dados.sort_values(by=recente,ascending = False).plot.bar(x="Unidade da Federação", y=recente, figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("BRASIL - GASTOS ATENDIMENTO SAÚDE")
plt.show()

# %% [markdown]
# # Entendendo gráficos

# %%
# mudar o data set = content/A152215189_28_143_208_atendimento.csv
dados [["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados.mean().index
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov', '2020/Dez',
#        '2021/Jan', '2021/Fev', '2021/Mar', 'Total'],
#       dtype='object', length=165)

# %%
colunas_usaveis = dados.mean().index
dados[colunas_usaveis].head()
# Out:
#    2007/Ago  2007/Set   2007/Out  ...    2021/Fev    2021/Mar         Total
# 0   4209.37  16397.03  133645.19  ...  6039419.59  4732441.04  996411254.68
# 1  10470.07  14001.71   86200.85  ...  2272733.90  1137341.65  450048530.47
# 2  35752.72  45570.64  416012.30  ... 13679358.06  6799060.80 1917247936.05
# 3   4785.91  11858.63   43852.67  ...  3044798.77  2381844.31  328876965.09
# 4 181159.29 433414.74 1893197.50  ... 23343222.94 13069564.31 4705309002.29
#
# [5 rows x 165 columns]

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  'Total']

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Mar         Total
# 0          11 Rondônia   4209.37  ...  4732441.04  996411254.68
# 1              12 Acre  10470.07  ...  1137341.65  450048530.47
# 2          13 Amazonas  35752.72  ...  6799060.80 1917247936.05
# 3           14 Roraima   4785.91  ...  2381844.31  328876965.09
# 4              15 Pará 181159.29  ... 13069564.31 4705309002.29
#
# [5 rows x 166 columns]

# %%
usaveis = usaveis.set_index('Unidade da Federação')
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996411254.68
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450048530.47
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917247936.05
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876965.09
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705309002.29
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309860092.59
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1020028272.64
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871069498.04
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280888802.74
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591836650.18
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660122027.15
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614919044.63
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8581189975.91
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236415402.51
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215853015.00
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791541570.52
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418737536.66
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405850698.58
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337389922.09
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41396408548.81
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681514706.67
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7835011163.40
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764391179.92
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324525096.33
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180119781.15
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973572261.43
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592422853.56
#
# [27 rows x 165 columns]

# %%
usaveis['2019/Ago']
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374933.66
# 22 Piauí                  17833872.84
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073542.40
# 25 Paraíba                19863848.57
# 26 Pernambuco             71735983.26
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77884805.29
# 31 Minas Gerais          161774658.77
# 32 Espírito Santo         29318260.49
# 33 Rio de Janeiro         83624113.30
# 35 São Paulo             303584114.00
# 41 Paraná                127174381.95
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98566147.88
# 50 Mato Grosso do Sul     19217982.14
# 51 Mato Grosso            16532335.42
# 52 Goiás                  38533573.53
# 53 Distrito Federal       21133361.51
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc['25 Paraíba']
# Out:
# 2007/Ago        97352.78
# 2007/Set       368130.43
# 2007/Out      1002088.64
# 2007/Nov      2149873.40
# 2007/Dez      5448177.36
#                 ...
# 2020/Dez     20355212.85
# 2021/Jan     20149018.68
# 2021/Fev     16996494.03
# 2021/Mar     12517894.05
# Total      2614919044.63
# Name: 25 Paraíba, Length: 165, dtype: float64

# %%
usaveis.T.plot(figsize=(10,7))

# %%
  usaveis.drop ('Total',axis=1)
# Out:
#                          2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   6039419.59   4732441.04
# 12 Acre                  10470.07   14001.71  ...   2272733.90   1137341.65
# 13 Amazonas              35752.72   45570.64  ...  13679358.06   6799060.80
# 14 Roraima                4785.91   11858.63  ...   3044798.77   2381844.31
# 15 Pará                 181159.29  433414.74  ...  23343222.94  13069564.31
# 16 Amapá                 33672.74  104822.98  ...   1534733.18    989155.40
# 17 Tocantins              4113.76   76633.06  ...    416534.32    928756.84
# 21 Maranhão             385330.18 1018352.93  ...  23260245.95  17294509.11
# 22 Piauí                220788.25  353468.67  ...  13636005.36   9542151.53
# 23 Ceará                357904.65  572356.18  ...  30186951.00  17173151.55
# 24 Rio Grande do Norte  134605.36  272088.08  ...  18186942.80   8733455.36
# 25 Paraíba               97352.78  368130.43  ...  16996494.03  12517894.05
# 26 Pernambuco           400640.85 1088340.42  ...  62259409.32  39472738.81
# 27 Alagoas              104243.75  174024.90  ...  12792571.64   8180887.21
# 28 Sergipe               27453.63   78565.19  ...   4129845.36   3081081.42
# 29 Bahia                135146.36  448349.75  ...  55544579.04  31314602.44
# 31 Minas Gerais         971394.37 2861781.50  ... 119877417.15  79780838.00
# 32 Espírito Santo        57408.11  284224.80  ...  25669612.63  15606368.11
# 33 Rio de Janeiro       469469.34  921646.57  ...  60873103.08  49149884.48
# 35 São Paulo           1665349.90 4434168.64  ... 268193064.06 177408317.71
# 41 Paraná               554800.22 1431708.01  ...  83130175.37  43480729.07
# 42 Santa Catarina       693955.05 1092964.12  ...  47429335.91  19375822.56
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  84404640.00  37798832.80
# 50 Mato Grosso do Sul   199556.12  573675.41  ...  11428462.42   4035989.77
# 51 Mato Grosso           63562.50  232444.62  ...  13207979.82   8835890.09
# 52 Goiás                179395.82  418053.58  ...  32253788.65  24867001.02
# 53 Distrito Federal     191951.47  769966.25  ...  19004029.87  14731938.43
#
# [27 rows x 164 columns]

# %%
  usaveis.drop ('Total',axis=1)
  usaveis = usaveis.drop ('Total',axis=1)

# %% [markdown]
# Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[1:4]
# Out:
# Index(['12 Acre', '13 Amazonas', '14 Roraima'], dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.sum(axis=1)
# Out:
# Unidade da Federação
# 11 Rondônia                996410650.35
# 12 Acre                    450047246.65
# 13 Amazonas               1917245104.64
# 14 Roraima                 328876551.40
# 15 Pará                   4705290466.69
# 16 Amapá                   309837994.87
# 17 Tocantins              1019990254.88
# 21 Maranhão               3871010362.58
# 22 Piauí                  2280874839.37
# 23 Ceará                  6591825335.83
# 24 Rio Grande do Norte    2660065804.91
# 25 Paraíba                2614895825.09
# 26 Pernambuco             8580915668.43
# 27 Alagoas                2236401471.26
# 28 Sergipe                1215843416.10
# 29 Bahia                  9791496136.10
# 31 Minas Gerais          20418205467.78
# 32 Espírito Santo         3405838975.80
# 33 Rio de Janeiro        10337229379.18
# 35 São Paulo             41386533231.31
# 41 Paraná                14681341476.16
# 42 Santa Catarina         7834872054.38
# 43 Rio Grande do Sul     12764274442.95
# 50 Mato Grosso do Sul     2324515373.43
# 51 Mato Grosso            2180110047.69
# 52 Goiás                  4973505000.10
# 53 Distrito Federal       2592308843.05
# dtype: float64

# %%
usaveis.T.plot(figsize=(10,7))
ax = plt.subplot()
#ax.legend(loc='center left', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# Desafio: explorar as cores da paleta para não repetir cores no estados

# %% [markdown]
# Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %% [markdown]
# # Aleatoriedade e mais explorações

# %%
usaveis[:5].T.plot(figsize=(10,6))

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %%
import numpy as np
np.random.seed(687942)
usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set  ...     2021/Fev    2021/Mar
# Unidade da Federação                         ...
# 32 Espírito Santo       57408.11  284224.80  ...  25669612.63 15606368.11
# 31 Minas Gerais        971394.37 2861781.50  ... 119877417.15 79780838.00
# 24 Rio Grande do Norte 134605.36  272088.08  ...  18186942.80  8733455.36
# 17 Tocantins             4113.76   76633.06  ...    416534.32   928756.84
# 53 Distrito Federal    191951.47  769966.25  ...  19004029.87 14731938.43
# 50 Mato Grosso do Sul  199556.12  573675.41  ...  11428462.42  4035989.77
# 16 Amapá                33672.74  104822.98  ...   1534733.18   989155.40
#
# [7 rows x 164 columns]

# %%
# acrescentando coluna "Total"
usaveis["Total"] = usaveis.sum(axis=1)
usaveis.head(5)
# Out:
#                       2007/Ago  2007/Set  ...    2021/Mar         Total
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  4732441.04  996410650.35
# 12 Acre               10470.07  14001.71  ...  1137341.65  450047246.65
# 13 Amazonas           35752.72  45570.64  ...  6799060.80 1917245104.64
# 14 Roraima             4785.91  11858.63  ...  2381844.31  328876551.40
# 15 Pará              181159.29 433414.74  ... 13069564.31 4705290466.69
#
# [5 rows x 165 columns]

# %% [markdown]
# # Ordenação e série temporal

# %%
usaveis.sort_values("Total")
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309837994.87
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876551.40
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450047246.65
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996410650.35
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1019990254.88
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215843416.10
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917245104.64
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180110047.69
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236401471.26
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280874839.37
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324515373.43
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592308843.05
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614895825.09
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660065804.91
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405838975.80
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871010362.58
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705290466.69
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973505000.10
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591825335.83
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7834872054.38
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8580915668.43
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791496136.10
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337229379.18
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764274442.95
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681341476.16
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418205467.78
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41386533231.31
#
# [27 rows x 165 columns]

# %%
usaveis.sort_values("Total", ascending=False)
# Out:
#                          2007/Ago   2007/Set  ...     2021/Mar          Total
# Unidade da Federação                          ...
# 35 São Paulo           1665349.90 4434168.64  ... 177408317.71 41386533231.31
# 31 Minas Gerais         971394.37 2861781.50  ...  79780838.00 20418205467.78
# 41 Paraná               554800.22 1431708.01  ...  43480729.07 14681341476.16
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  37798832.80 12764274442.95
# 33 Rio de Janeiro       469469.34  921646.57  ...  49149884.48 10337229379.18
# 29 Bahia                135146.36  448349.75  ...  31314602.44  9791496136.10
# 26 Pernambuco           400640.85 1088340.42  ...  39472738.81  8580915668.43
# 42 Santa Catarina       693955.05 1092964.12  ...  19375822.56  7834872054.38
# 23 Ceará                357904.65  572356.18  ...  17173151.55  6591825335.83
# 52 Goiás                179395.82  418053.58  ...  24867001.02  4973505000.10
# 15 Pará                 181159.29  433414.74  ...  13069564.31  4705290466.69
# 21 Maranhão             385330.18 1018352.93  ...  17294509.11  3871010362.58
# 32 Espírito Santo        57408.11  284224.80  ...  15606368.11  3405838975.80
# 24 Rio Grande do Norte  134605.36  272088.08  ...   8733455.36  2660065804.91
# 25 Paraíba               97352.78  368130.43  ...  12517894.05  2614895825.09
# 53 Distrito Federal     191951.47  769966.25  ...  14731938.43  2592308843.05
# 50 Mato Grosso do Sul   199556.12  573675.41  ...   4035989.77  2324515373.43
# 22 Piauí                220788.25  353468.67  ...   9542151.53  2280874839.37
# 27 Alagoas              104243.75  174024.90  ...   8180887.21  2236401471.26
# 51 Mato Grosso           63562.50  232444.62  ...   8835890.09  2180110047.69
# 13 Amazonas              35752.72   45570.64  ...   6799060.80  1917245104.64
# 28 Sergipe               27453.63   78565.19  ...   3081081.42  1215843416.10
# 17 Tocantins              4113.76   76633.06  ...    928756.84  1019990254.88
# 11 Rondônia               4209.37   16397.03  ...   4732441.04   996410650.35
# 12 Acre                  10470.07   14001.71  ...   1137341.65   450047246.65
# 14 Roraima                4785.91   11858.63  ...   2381844.31   328876551.40
# 16 Amapá                 33672.74  104822.98  ...    989155.40   309837994.87
#
# [27 rows x 165 columns]

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False) 
ordenado_por_total = ordenado_por_total.drop(["Total"], axis=1)

ordenado_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 268193064.06 177408317.71
# 31 Minas Gerais       971394.37 2861781.50  ... 119877417.15  79780838.00
# 41 Paraná             554800.22 1431708.01  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     469469.34  921646.57  ...  60873103.08  49149884.48
#
# [5 rows x 164 columns]

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
#colunas_interessadas = (usaveis['41 Paraná'])
#ordenado_por_total = ordenado_por_total[colunas_interessadas]
ordenado_por_total[colunas_interessadas].head()
#ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
#                          2008/Fev     2008/Mar  ...     2021/Fev     2021/Mar
# Unidade da Federação                            ...
# 35 São Paulo         172961999.58 170556696.16  ... 268193064.06 177408317.71
# 31 Minas Gerais       70301089.50  79119005.51  ... 119877417.15  79780838.00
# 41 Paraná             48855046.46  55611791.07  ...  83130175.37  43480729.07
# 43 Rio Grande do Sul  45897704.82  52928695.92  ...  84404640.00  37798832.80
# 33 Rio de Janeiro     44128159.73  42900847.02  ...  60873103.08  49149884.48
#
# [5 rows x 158 columns]

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# # DESAFIOS

# %% [markdown]
# Desafio 01: Escolher uma palete de cores mais adequada do matplotlib.

# %%
nc = len(ordenado_por_total)
c = plt.cm.nipy_spectral(np.linspace(0, 1, nc))
grafico = ordenado_por_total.T.plot(figsize=(10,6), color=c)
grafico.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
grafico.yaxis.set_major_formatter(ticker.StrMethodFormatter("R$ {x:,.2f}"))
plt.title("Gastos por atendimentos hospitalares - Brasil")
plt.show()

# %% [markdown]
# Desafio 02: Adicionar uma coluna mostrando a região (Norte, Nodeste, Sul, Suldeste e Centro-Oeste) de cada estado.

# %%
# inserindo coluna com a regiado de cada estado
regiao =  {'1':'Norte', '2':'Nordeste', '3':'Sudeste', '4':'Sul', '5':'Centro-Oeste'}
fr = lambda x: regiao[x.name[0]]
usaveis['Região'] = usaveis.apply(fr, axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set  ...         Total  Região
# Unidade da Federação                      ...
# 11 Rondônia            4209.37  16397.03  ...  996410650.35   Norte
# 12 Acre               10470.07  14001.71  ...  450047246.65   Norte
# 13 Amazonas           35752.72  45570.64  ... 1917245104.64   Norte
# 14 Roraima             4785.91  11858.63  ...  328876551.40   Norte
# 15 Pará              181159.29 433414.74  ... 4705290466.69   Norte
#
# [5 rows x 166 columns]

# %% [markdown]
# Desafio 03: Formatar o gráfico de custos por mês dos 5 estados, deixando ele agradável (Bonitão, segundo o Gui)

# %%
import seaborn as sns
sns.set_palette(sns.color_palette("gist_rainbow", 5))
ordenado_por_total[:5].T.plot(figsize=(10,6))
plt.title("Estados com maior gasto na saúde", fontsize=20)
plt.xlabel("Período", fontsize=15)
plt.ylabel("R$ milhões", fontsize=15)
plt.legend(title="UF", bbox_to_anchor = (1.30, 1), frameon=True)
plt.show()

# %% [markdown]
# Desafio 04: Adicione o seu estado aos 5 estados plotados anteriormente

# %%
usaveis.sum(axis=1)
# Out:
# Unidade da Federação
# 11 Rondônia               1992821300.70
# 12 Acre                    900094493.30
# 13 Amazonas               3834490209.28
# 14 Roraima                 657753102.80
# 15 Pará                   9410580933.38
# 16 Amapá                   619675989.74
# 17 Tocantins              2039980509.76
# 21 Maranhão               7742020725.16
# 22 Piauí                  4561749678.74
# 23 Ceará                 13183650671.66
# 24 Rio Grande do Norte    5320131609.82
# 25 Paraíba                5229791650.18
# 26 Pernambuco            17161831336.86
# 27 Alagoas                4472802942.52
# 28 Sergipe                2431686832.20
# 29 Bahia                 19582992272.20
# 31 Minas Gerais          40836410935.56
# 32 Espírito Santo         6811677951.60
# 33 Rio de Janeiro        20674458758.36
# 35 São Paulo             82773066462.62
# 41 Paraná                29362682952.32
# 42 Santa Catarina        15669744108.76
# 43 Rio Grande do Sul     25528548885.90
# 50 Mato Grosso do Sul     4649030746.86
# 51 Mato Grosso            4360220095.38
# 52 Goiás                  9947010000.20
# 53 Distrito Federal       5184617686.10
# dtype: float64

# %%
compara = ordenado_por_total.head(5).index.to_list()
compara.append("25 Paraíba")
compara
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '25 Paraíba']

# %%
compara.append("53 Distrito Federal")
compara
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '25 Paraíba',
#  '53 Distrito Federal']

# %%
compara.append("42 Santa Catarina")
compara
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '25 Paraíba',
#  '53 Distrito Federal',
#  '42 Santa Catarina']

# %%
#definindo cores distintas para cada UF
nc = len(ordenado_por_total)
colors = plt.cm.nipy_spectral(np.linspace(0, 3, nc))
# - - -
sns.set_palette(sns.color_palette("gist_rainbow", 6))
ordenado_por_total.loc[compara].T.plot(figsize=(12,8), color=colors)
plt.title("PB, SC, DF vs estados com maior gasto na saúde", fontsize=20)
plt.xlabel("Período", fontsize=15)
plt.ylabel("R$ milhões", fontsize=15)
plt.legend(title="UF", bbox_to_anchor = (1.30, 1), frameon=True)
plt.show()

# %% [markdown]
# Desafio 05: Buscar os casos de dengue no Brasil (época de maior número de casos e regiões mais atingidas) e se os picos de alguns estados em fevereiro e verão de modo geral, pode ser reflexos dos casos de dengue

# %% [markdown]
# Casos de dengue no país aumentam 190% em 2013, diz governo.
#
# http://g1.globo.com/bemestar/noticia/2013/02/casos-de-dengue-no-pais-aumentam-190-no-comeco-de-2013-diz-governo.html
#
# Disponível em 29/05/2021

# %% [markdown]
# Desafio 06: Plotar o gráfico dos custos apenas dos estados da região sudeste e verificar se os picos de 2013/Fev teve comportamento similar em todos os demais estados da região

# %%
sudeste = usaveis.loc[usaveis['Região'] == 'Sudeste']
sudeste
# Out:
#                        2007/Ago   2007/Set  ...          Total   Região
# Unidade da Federação                        ...
# 31 Minas Gerais       971394.37 2861781.50  ... 20418205467.78  Sudeste
# 32 Espírito Santo      57408.11  284224.80  ...  3405838975.80  Sudeste
# 33 Rio de Janeiro     469469.34  921646.57  ... 10337229379.18  Sudeste
# 35 São Paulo         1665349.90 4434168.64  ... 41386533231.31  Sudeste
#
# [4 rows x 166 columns]

# %%
sudeste = sudeste.drop(['Região'], axis=1)
sudeste = sudeste.drop(['Total'], axis=1)

# %%
sns.set_palette(sns.color_palette("gist_rainbow", 6))
sudeste.T.plot(figsize=(10,8))
plt.title("Sudeste Brasileiro", fontsize=15)
plt.xlabel("Período", fontsize=15)
plt.ylabel("Gastos", fontsize=15)
plt.legend(title="UF", bbox_to_anchor = (1.30, 1), frameon=True)
plt.grid(color='b', linestyle='-', linewidth=0.4)
plt.show()

# %% [markdown]
# Desafio 07: Adicionar seu estado escolhido novamente, deixe o gráfico informativo e tire conclusões sobre seus estados comparando com os demais. Tire suas conclusões e compartilhe com a gente.

# %%
# Adicionando estados de moradia familiar
nc = len(ordenado_por_total)
colors = plt.cm.nipy_spectral(np.linspace(0, 3, nc))
# - - -
sns.set_palette(sns.color_palette("gist_rainbow", 6))
ordenado_por_total.loc[compara].T.plot(figsize=(12,8), color=colors)
plt.title("PB, SC, DF vs estados com maior gasto na saúde", fontsize=20)
plt.xlabel("Período", fontsize=15)
plt.ylabel("R$ milhões", fontsize=15)
plt.legend(title="UF", bbox_to_anchor = (1.30, 1), frameon=True)
plt.show()

# %% [markdown]
# Fica claro no gráfico que os estados SC, DF e PB tem gastos com saúde bem inferior aos cinco estados com maior gasto, no período de análise.

# %% [markdown]
# # Fugindo de más práticas

# %%
ordenado_por_total= ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
ordenado_por_total[ordenado_por_total.columns[47:]].head(3).T.plot(figsize=(10,6))

# %%
meses_filtrados = ordenado_por_total.columns[47:150] 
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
# 29/05/2021 Sábado 09:29h
# OBservação sobre esse gráfico específico: ponto importante sobre a informação passada no gráfico.
# O corte efetuado nos dados, tanto no eixo "x" quanto no eixo "y" pode
# deturpar a interpretação final do gráfico promovendo uma falsa sensação de segurança
# " quando limitamos a visão consequentemente deturpamos a interpretação dos dados"
# ótimo sassunto para tese de doutorado
# " um cientista de dadss deve comprometer-se a passar a informação adequada no gráfico"
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
# OBservação com relação a esse gráfico
# CUIDADO: uma história pode estar sendo contada de que os gastos estão caindo
# mas a amostragem de dados foi novamente limitada a um certo período
# Iaao porque aqui foram escolhidos somente 12 meses. Comsiderando o range
# dados para analies é um período muito pequeno para interpretação massima de dados.
# MUITO CUIDADO: janela x/y de qualquer gráfico apresentada no gráfico
# Um cientista de dados deve zelar pela apresentação veridica dos dados
# dentro do range x/y proposto defendendo a informação adequada
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Desafio 01: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações

# %% [markdown]
# Desafio 02: Reflita sobre os problemas na manipulação de dados e discuta esse assunto no Discord.

# %% [markdown]
# # Alternativas de visualizações

# %%
ordenado_por_total.columns[-1]
# Out:
# '2021/Mar'

# %%
mes_mais_recente = ordenado_por_total.columns[-1]

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
gastos_do_mais_recente.plot()

# %%
# todo gráfico de comida não serve para representar os dados de forma
# adequada
# TIPO DE GRÁFICO E DESVANTAGENS DO TIPO PIZZA
# legenda não ajuda
# fatias não representam bem os dados
# dificil comparação entre áreas do círculo]
# fora de ordem fica mais complicado a análise de grandezas
gastos_do_mais_recente.plot(kind='pie')

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.61
# 31 Minas Gerais          1.62
# 41 Paraná                0.88
# 43 Rio Grande do Sul     0.77
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.64
# 26 Pernambuco            0.80
# 42 Santa Catarina        0.39
# 23 Ceará                 0.35
# 52 Goiás                 0.51
# 15 Pará                  0.27
# 21 Maranhão              0.35
# 32 Espírito Santo        0.32
# 24 Rio Grande do Norte   0.18
# 25 Paraíba               0.25
# 53 Distrito Federal      0.30
# 50 Mato Grosso do Sul    0.08
# 22 Piauí                 0.19
# 27 Alagoas               0.17
# 51 Mato Grosso           0.18
# 13 Amazonas              0.14
# 28 Sergipe               0.06
# 17 Tocantins             0.02
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.05
# 16 Amapá                 0.02
# Name: 2021/Mar, dtype: float64

# %% [markdown]
# DESAFIO: criar a tabela de comparação com o seu estado atual

# %%
compara_pb = gastos_do_mais_recente / gastos_do_mais_recente.loc["25 Paraíba"]
compara_pb
# Out:
# Unidade da Federação
# 35 São Paulo             14.17
# 31 Minas Gerais           6.37
# 41 Paraná                 3.47
# 43 Rio Grande do Sul      3.02
# 33 Rio de Janeiro         3.93
# 29 Bahia                  2.50
# 26 Pernambuco             3.15
# 42 Santa Catarina         1.55
# 23 Ceará                  1.37
# 52 Goiás                  1.99
# 15 Pará                   1.04
# 21 Maranhão               1.38
# 32 Espírito Santo         1.25
# 24 Rio Grande do Norte    0.70
# 25 Paraíba                1.00
# 53 Distrito Federal       1.18
# 50 Mato Grosso do Sul     0.32
# 22 Piauí                  0.76
# 27 Alagoas                0.65
# 51 Mato Grosso            0.71
# 13 Amazonas               0.54
# 28 Sergipe                0.25
# 17 Tocantins              0.07
# 11 Rondônia               0.38
# 12 Acre                   0.09
# 14 Roraima                0.19
# 16 Amapá                  0.08
# Name: 2021/Mar, dtype: float64

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["33 Rio de Janeiro"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           3.61
# 31 Minas Gerais        1.62
# 41 Paraná              0.88
# 43 Rio Grande do Sul   0.77
# 33 Rio de Janeiro      1.00
# Name: 2021/Mar, dtype: float64

# %% [markdown]
# Desafio 01: Buscar na documentação do Matplotlib como colocar um grid nos gráficos e adicionar nos gráficos de barra.

# %%
gastos_do_mais_recente.plot(kind='bar').grid()

# %%
# Esse gráfico é a melhor forma de vizualização de dados
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar', figsize=(10,6)).grid(True)

# %% [markdown]
# Desafio 02: Fazer um gráfico e uma tabela do gasto dos outros estados em função do seu estado, ou qualquer outro de interesse.

# %%
# Comparando gastos da Paraíba com os demais estados brasileiros
compara_pb = compara_pb.sort_values(ascending=False)
compara_pb.plot(kind='bar', figsize=(10,6)).grid(color='gray', linestyle='-', linewidth=0.4)

# %% [markdown]
# Desafio 03: Fazer o cálculo proporcional a população do seu estado e mais um a sua escolha.

# %% [markdown]
# Desafio 04: Faça uma análise dos dados analisados, levante hipóteses e compartilhe com a gente no Discord.

# %% [markdown]
# Desafio 05: Reproduza as análises feitas em aulas, refletindo e levantando hipóteses.

# %% [markdown]
# Super Desafio: Escolha outro valor fora o valor aprovado no TABNET e explore estes dados. Esse será nosso projeto do módulo, mais detalhes no Desafio do módulo 1 na página do bootcamp.

# %% [markdown]
# # Conclusão

# %% [markdown]
# Conhecimento indispensável para todos os profissionais que lidam com grandes qantidades de dados e precisam compilar de forma objetiva, adequada e honesta
# um contexto sobre uma determinada pesquisa e/ou estudo.

# %% [markdown]
# # M02: Visualização de dados com Seaborn e Matplotlib
# 01/06/2021 8h

# %% [markdown]
# # Usando fontes alternativas de dados

# %%
# A importância dos dados relativos e absolutos
import matplotlib.pyplot as plt, matplotlib.ticker as ticker
recente = dados.columns[-2]
ax = dados.sort_values(by=recente,ascending = False).plot.bar(x="Unidade da Federação", y=recente, figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("BRASIL - GASTOS ATENDIMENTO SAÚDE")
plt.show()

# %%
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo        177.41
# 31 Minas Gerais      79.78
# 33 Rio de Janeiro    49.15
# 41 Paraná            43.48
# 26 Pernambuco        39.47
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente/ gastos_do_mais_recente.sum()
# Out:
# Unidade da Federação
# 35 São Paulo             0.27
# 31 Minas Gerais          0.12
# 33 Rio de Janeiro        0.08
# 41 Paraná                0.07
# 26 Pernambuco            0.06
# 43 Rio Grande do Sul     0.06
# 29 Bahia                 0.05
# 52 Goiás                 0.04
# 42 Santa Catarina        0.03
# 21 Maranhão              0.03
# 23 Ceará                 0.03
# 32 Espírito Santo        0.02
# 53 Distrito Federal      0.02
# 15 Pará                  0.02
# 25 Paraíba               0.02
# 22 Piauí                 0.01
# 51 Mato Grosso           0.01
# 24 Rio Grande do Norte   0.01
# 27 Alagoas               0.01
# 13 Amazonas              0.01
# 11 Rondônia              0.01
# 50 Mato Grosso do Sul    0.01
# 28 Sergipe               0.00
# 14 Roraima               0.00
# 12 Acre                  0.00
# 16 Amapá                 0.00
# 17 Tocantins             0.00
# Name: 2021/Mar, dtype: float64

# %%
gastos_proporcionas = gastos_do_mais_recente/ gastos_do_mais_recente.sum()
gastos_proporcionas.plot(kind='bar')

# %%
ibge_estimativas = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Alura/Bootcamp de Data Science/data/POP2018_20210331.xls")
ibge_estimativas.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2018  ...          Unnamed: 2
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO                                                                  ...  POPULAÇÃO ESTIMADA
# 1                                             Brasil                                                                  ...           208494900
# 2                                       Região Norte                                                                  ...            18182253
# 3                                           Rondônia                                                                  ...             1757589
# 4                                               Acre                                                                  ...              869265
#
# [5 rows x 3 columns]

# %%
dados_da_populacao = '''Posição 	Unidade federativa 	População 	% da pop. total 	País comparável
(habitantes)

1 	 São Paulo 	46 289 333 	21,9% 	Flag of Spain.svg Espanha (46 439 864)
2 	 Minas Gerais 	21 292 666 	10,1% 	Sri Lanka (20 675 000)
3 	 Rio de Janeiro 	17 366 189 	8,2% 	 Países Baixos (16 922 900)
4 	Bahia Bahia 	14 930 634 	7,1% 	Chade (14 037 000)
5 	 Paraná 	11 516 840 	5,4% 	 Bolívia (11 410 651)
6 	 Rio Grande do Sul 	11 422 973 	5,4% 	 Bélgica (11 250 659)
7 	 Pernambuco 	9 616 621 	4,5% 	 Bielorrússia (9 485 300)
8 	 Ceará 	9 187 103 	4,3% 	 Emirados Árabes Unidos (9 157 000)
9 	Pará Pará 	8 690 745 	4,1% 	 Áustria (8 602 112)
10 	 Santa Catarina 	7 252 502 	3,4% 	 Sérvia (7 114 393)
11 	 Maranhão 	7 114 598 	3,4% 	 Paraguai (7 003 406)
12 	 Goiás 	7 113 540 	3,4% 	 Paraguai (7 003 406)
13 	 Amazonas 	4 207 714 	2,0% 	Líbano (4 168 000)
14 	 Espírito Santo 	4 064 052 	1,9% 	Líbano (4 168 000)
15 	 Paraíba 	4 039 277 	1,9% 	Líbano (4 168 000)
16 	 Rio Grande do Norte 	3 534 165 	1,7% 	Uruguai (3 415 866)
17 	 Mato Grosso 	3 526 220 	1,7% 	Uruguai (3 415 866)
18 	 Alagoas 	3 351 543 	1,6% 	Uruguai (3 415 866)
19 	 Piauí 	3 281 480 	1,6% 	Kuwait (3 268 431)
20 	 Distrito Federal 	3 055 149 	1,4% 	 Lituânia (2 900 787)
21 	 Mato Grosso do Sul 	2 809 394 	1,3% 	 Jamaica (2 717 991)
22 	 Sergipe 	2 318 822 	1,1% 	Namíbia (2 280 700)
23 	 Rondônia 	1 796 460 	0,8% 	Gabão (1 725 000)
24 	 Tocantins 	1 590 248 	0,7% 	 Bahrein (1 359 800)
25 	 Acre 	894 470 	0,4% 	Fiji (859 178)
26 	 Amapá 	861 773 	0,4% 	Fiji (859 178)
27 	 Roraima 	631 181 	0,3% 	 Luxemburgo (562 958)'''
#fonte: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
import pandas as pd
from io import StringIO
dados_da_populacao_io = StringIO(dados_da_populacao)
populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
populacao.head()
populacao = populacao.dropna()
#populacao["populacao"] = populacao["População"].str.replace(" ", "").astype(int)
#populacao["uf"] = populacao["Unidade federativa"]
#populacao.rename(columns={'População':'populacao'}inplace=True)
#display(populacao.head())
#display(populacao.info())
populacao
# Out:
#    Posição   ...                         País comparável
# 1        1   ...  Flag of Spain.svg Espanha (46 439 864)
# 2        2   ...                  Sri Lanka (20 675 000)
# 3        3   ...              Países Baixos (16 922 900)
# 4        4   ...                      Chade (14 037 000)
# 5        5   ...                    Bolívia (11 410 651)
# 6        6   ...                    Bélgica (11 250 659)
# 7        7   ...                Bielorrússia (9 485 300)
# 8        8   ...      Emirados Árabes Unidos (9 157 000)
# 9        9   ...                     Áustria (8 602 112)
# 10      10   ...                      Sérvia (7 114 393)
# 11      11   ...                    Paraguai (7 003 406)
# 12      12   ...                    Paraguai (7 003 406)
# 13      13   ...                      Líbano (4 168 000)
# 14      14   ...                      Líbano (4 168 000)
# 15      15   ...                      Líbano (4 168 000)
# 16      16   ...                     Uruguai (3 415 866)
# 17      17   ...                     Uruguai (3 415 866)
# 18      18   ...                     Uruguai (3 415 866)
# 19      19   ...                      Kuwait (3 268 431)
# 20      20   ...                    Lituânia (2 900 787)
# 21      21   ...                     Jamaica (2 717 991)
# 22      22   ...                     Namíbia (2 280 700)
# 23      23   ...                       Gabão (1 725 000)
# 24      24   ...                     Bahrein (1 359 800)
# 25      25   ...                          Fiji (859 178)
# 26      26   ...                          Fiji (859 178)
# 27      27   ...                    Luxemburgo (562 958)
#
# [27 rows x 5 columns]

# %% [markdown]
# DESAFIO ; ler a fonte de dados na wikipedia utilçizando outra forma de leitura

# %% [markdown]
# # Manipulação e junção de tabelas

# %%
populacao.head()
# Out:
#   Posição   ...                         País comparável
# 1       1   ...  Flag of Spain.svg Espanha (46 439 864)
# 2       2   ...                  Sri Lanka (20 675 000)
# 3       3   ...              Países Baixos (16 922 900)
# 4       4   ...                      Chade (14 037 000)
# 5       5   ...                    Bolívia (11 410 651)
#
# [5 rows x 5 columns]
